# %%
# GPU사용을 확인
import torch

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

print(device)

# 출력은 cuda로 나와야함
# Out:
# cuda

# %%
import os
os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"

print('현재 작업 경로 : ', os.getcwd())
# 사용하고자하는 폴더
os.chdir('C:/Users/User/Documents/workspace/GrauteProject/yolov5')
print('변경 작업 경로 : ', os.getcwd())
# Out:
# 현재 작업 경로 :  C:\Users\User\Documents\workspace\GrauteProject\training
# 변경 작업 경로 :  C:\Users\User\Documents\workspace\GrauteProject\yolov5

# %%
# yolov5를 사용하기 위한 의존성
#git clone https://github.com/ultralytics/yolov5
# cd yolov5
# %pip install -qr requirements.txt
# %pip install -q roboflow
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements.txt'
# Note: you may need to restart the kernel to use updated packages.

# %%
import yaml

# %%
# dataset위치 잡기
data_dir = 'C:/Users/User/Documents/workspace/GrauteProject/training/dataset/drone.v6i.yolov5pytorch'
data_yaml = 'C:/Users/User/Documents/workspace/GrauteProject/training/dataset/drone.v6i.yolov5pytorch/data.yaml'

# %%
with open(data_yaml) as f:
  film = yaml.load(f, Loader=yaml.FullLoader)
  display(film)
# Out:
# {'names': ['drone'],
#  'nc': 1,
#  'roboflow': {'license': 'CC BY 4.0',
#   'project': 'drone-80mc8',
#   'url': 'https://universe.roboflow.com/drone-za1rm/drone-80mc8/dataset/6',
#   'version': 6,
#   'workspace': 'drone-za1rm'},
#  'test': '../test/images',
#  'train': 'C:/Users/User/Documents/workspace/GrauteProject/training/dataset/drone.v6i.yolov5pytorch/train/images',
#  'val': 'C:/Users/User/Documents/workspace/GrauteProject/training/dataset/drone.v6i.yolov5pytorch/valid/images'}

# %%
film['train'] = 'C:/Users/User/Documents/workspace/GrauteProject/training/dataset/drone.v6i.yolov5pytorch/train/images'
film['val'] = 'C:/Users/User/Documents/workspace/GrauteProject/training/dataset/drone.v6i.yolov5pytorch/valid/images'

with open(data_yaml, 'w') as f:
  yaml.dump(film, f)

print('변경된 yaml 파일 : ')
with open(data_yaml) as f:
  film = yaml.load(f, Loader=yaml.FullLoader)
  display(film)
# Out:
# 변경된 yaml 파일 :
# {'names': ['drone'],
#  'nc': 1,
#  'roboflow': {'license': 'CC BY 4.0',
#   'project': 'drone-80mc8',
#   'url': 'https://universe.roboflow.com/drone-za1rm/drone-80mc8/dataset/6',
#   'version': 6,
#   'workspace': 'drone-za1rm'},
#  'test': '../test/images',
#  'train': 'C:/Users/User/Documents/workspace/GrauteProject/training/dataset/drone.v6i.yolov5pytorch/train/images',
#  'val': 'C:/Users/User/Documents/workspace/GrauteProject/training/dataset/drone.v6i.yolov5pytorch/valid/images'}

# %%
# !python train.py --img 416 --batch 16 --epochs 50 --data {data_yaml} --weights yolov5s.pt --cache
# Out:
# train: weights=yolov5s.pt, cfg=, data=C:/Users/User/Documents/workspace/GrauteProject/training/dataset/drone.v6i.yolov5pytorch/data.yaml, hyp=data\hyps\hyp.scratch-low.yaml, epochs=50, batch_size=16, imgsz=416, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, evolve_population=data\hyps, resume_evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs\train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest, ndjson_console=False, ndjson_file=False
# github: up to date with https://github.com/ultralytics/yolov5
# YOLOv5  v7.0-297-gd07d0cf6 Python-3.12.2 torch-2.2.2+cu121 CUDA:0 (NVIDIA GeForce RTX 4070 Ti, 12282MiB)
#
# ...
